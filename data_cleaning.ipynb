# %%
# importing  the library
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('students_data1.csv')
df
# Out:
#     student_id           name   age  gender grade  math_score english_score  \
# 0          100     jane smith  16.0  female    11        75.0           NaN
# 1          101       John Doe  16.0    Male  10th        74.0            95
# 2          102       Chris P.   NaN    MALE    10         NaN       missing
# 3          103     jane smith  16.0  FEMALE    10         NaN       missing
# 4          104    Sara O'Neil  16.0    male    11         NaN            96
# 5          105  Mike O’Reilly  16.0  Female    10         NaN           NaN
# 6          106       ali Khan  17.0  female    11        64.0           NaN
# 7          107    Sara O'Neil  17.0  female    12         NaN            63
# 8          108  Mike O’Reilly  16.0  Female    12        80.0       missing
# 9          109   Robert Brown  17.0  female    12         NaN       missing
# 10         110      lucy gray  17.0    male  11th        65.0            67
# ...

# %%
df.head()
# Out:
#    student_id         name   age  gender grade  math_score english_score  \
# 0         100   jane smith  16.0  female    11        75.0           NaN
# 1         101     John Doe  16.0    Male  10th        74.0            95
# 2         102     Chris P.   NaN    MALE    10         NaN       missing
# 3         103   jane smith  16.0  FEMALE    10         NaN       missing
# 4         104  Sara O'Neil  16.0    male    11         NaN            96
#
#    science_score enrolled_date            remarks
# 0             66    2022-06-10          excellent
# 1             94    10-06-2022               GOOD
# 2             69    06/12/2022  needs improvement
# 3             62    10-06-2022            average
# 4             64    2022-06-10               GOOD

# %%
# explore the data
df.shape
# Out:
# (31, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     31 non-null     int64
#  1   name           31 non-null     str
#  2   age            28 non-null     float64
#  3   gender         31 non-null     str
#  4   grade          31 non-null     str
#  5   math_score     13 non-null     float64
#  6   english_score  23 non-null     str
#  7   science_score  31 non-null     int64
#  8   enrolled_date  31 non-null     str
#  9   remarks        31 non-null     str
# dtypes: float64(2), int64(2), str(6)
# memory usage: 2.6 KB

# %%
df.describe()
# Out:
#        student_id        age  math_score  science_score
# count   31.000000  28.000000   13.000000      31.000000
# mean   114.967742  16.785714   74.000000      79.903226
# std      9.038746   0.629941   11.510864      13.095431
# min    100.000000  16.000000   64.000000      62.000000
# 25%    107.500000  16.000000   65.000000      66.500000
# 50%    115.000000  17.000000   73.000000      83.000000
# 75%    122.500000  17.000000   75.000000      90.500000
# max    129.000000  18.000000  100.000000     100.000000

# %%
# Handle missing values
df.isnull().sum()
# Out:
# student_id        0
# name              0
# age               3
# gender            0
# grade             0
# math_score       18
# english_score     8
# science_score     0
# enrolled_date     0
# remarks           0
# dtype: int64

# %%
# fill missing values
df['age'].fillna(df['age'].median(), inplace=True)
df['age'] = df['age'].fillna(0).astype(int)
df['math_score'] = pd.to_numeric(df['math_score'], errors='coerce')
df['math_score'] = df['math_score'].fillna(0).astype(int)
df['english_score'] = pd.to_numeric(df['english_score'], errors='coerce')
df['english_score'] = df['english_score'].fillna(0).astype(int)
# Out:
# C:\Users\MEGHANA\AppData\Local\Temp\ipykernel_6492\2887949038.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df[['age','math_score','english_score']].head()
df.isnull().sum()
# Out:
# student_id       0
# name             0
# age              0
# gender           0
# grade            0
# math_score       0
# english_score    0
# science_score    0
# enrolled_date    0
# remarks          0
# dtype: int64

# %%
# remove duplicate records
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates()
# Out:
#     student_id           name  age  gender grade  math_score  english_score  \
# 0          100     jane smith   16  female    11          75              0
# 1          101       John Doe   16    Male  10th          74             95
# 2          102       Chris P.    0    MALE    10           0              0
# 3          103     jane smith   16  FEMALE    10           0              0
# 4          104    Sara O'Neil   16    male    11           0             96
# 5          105  Mike O’Reilly   16  Female    10           0              0
# 6          106       ali Khan   17  female    11          64              0
# 7          107    Sara O'Neil   17  female    12           0             63
# 8          108  Mike O’Reilly   16  Female    12          80              0
# 9          109   Robert Brown   17  female    12           0              0
# 10         110      lucy gray   17    male  11th          65             67
# ...

# %%
df['grade'] = df['grade'].astype(str).str.strip().str.lower()

df['grade'] = df['grade'].replace(grade_map)

# %%
#Standardize and Clean Text Data Clean text columns by:
df['name'] = df['name'].str.strip()
df['gender'] = df['gender'].str.strip()
df['remarks'] = df['remarks'].str.strip()

# %%
df['name'] = df['name'].str.upper()
df['gender'] = df['gender'].str.upper()
df['remarks'] = df['remarks'].str.upper()

# %%
# Rename Columns
df.columns = df.columns.str.strip().str.upper()

# %%
# Final Clean Dataset
df.head(30)
# Out:
#     STUDENT_ID           NAME  AGE  GENDER GRADE  MATH_SCORE  ENGLISH_SCORE  \
# 0          100     JANE SMITH   16  FEMALE    XI          75              0
# 1          101       JOHN DOE   16    MALE     X          74             95
# 2          102       CHRIS P.    0    MALE     X           0              0
# 3          103     JANE SMITH   16  FEMALE     X           0              0
# 4          104    SARA O'NEIL   16    MALE    XI           0             96
# 5          105  MIKE O’REILLY   16  FEMALE     X           0              0
# 6          106       ALI KHAN   17  FEMALE    XI          64              0
# 7          107    SARA O'NEIL   17  FEMALE   XII           0             63
# 8          108  MIKE O’REILLY   16  FEMALE   XII          80              0
# 9          109   ROBERT BROWN   17  FEMALE   XII           0              0
# 10         110      LUCY GRAY   17    MALE    XI          65             67
# ...
